# %%
import pandas as pd 
import numpy as np

# %%
judges = pd.read_csv("judges.csv")
len(judges)
# Out:
# 1003

# %%
judges['gender'].value_counts(dropna = False, normalize = True) # we coerce W and F to female
# Out:
# gender
# M    0.885344
# F    0.097707
# W    0.016949
# Name: proportion, dtype: float64

# %%
judges['gender'].value_counts(dropna = False)
# Out:
# gender
# M    888
# F     98
# W     17
# Name: count, dtype: int64

# %%
for col in ['nonblack', 'marijuana', 'cocaine', 'crack', 'heroin', 'pcp', 'otherdrug', 'nondrug', 'priorarr', 'priorfelarr', 'priordrugarr', 'priorfeldrugarr', 'priorcon', 'priorfelcon', 'priordrugcon', 'priorfeldrugcon', 'pwid', 'dist']:
    print(judges[col].value_counts(dropna = False, normalize = True))
# Out:
# nonblack
# 0    0.975075
# 1    0.024925
# Name: proportion, dtype: float64
# marijuana
# 0    0.809571
# 1    0.190429
# Name: proportion, dtype: float64
# cocaine
# 0    0.600199
# 1    0.399801
# Name: proportion, dtype: float64
# crack
# 0    0.803589
# 1    0.196411
# Name: proportion, dtype: float64
# heroin
# 0    0.73679
# 1    0.26321
# Name: proportion, dtype: float64
# pcp
# 0    0.953141
# 1    0.046859
# Name: proportion, dtype: float64
# otherdrug
# 0    0.967099
# 1    0.032901
# Name: proportion, dtype: float64
# nondrug
# 0    0.870389
# 1    0.128614
# 2    0.000997
# Name: proportion, dtype: float64
# priorarr
# 1    0.85344
# 0    0.14656
# Name: proportion, dtype: float64
# priorfelarr
# 1    0.718843
# 0    0.281157
# Name: proportion, dtype: float64
# priordrugarr
# 1    0.721834
# 0    0.278166
# Name: proportion, dtype: float64
# priorfeldrugarr
# 1    0.55334
# 0    0.44666
# Name: proportion, dtype: float64
# priorcon
# 1    0.670987
# 0    0.329013
# ...

# %%
for col in ['nonblack', 'marijuana', 'cocaine', 'crack', 'heroin', 'pcp', 'otherdrug', 'nondrug', 'priorarr', 'priorfelarr', 'priordrugarr', 'priorfeldrugarr', 'priorcon', 'priorfelcon', 'priordrugcon', 'priorfeldrugcon', 'pwid', 'dist']:
    print(judges[col].value_counts(dropna = False))
# Out:
# nonblack
# 0    978
# 1     25
# Name: count, dtype: int64
# marijuana
# 0    812
# 1    191
# Name: count, dtype: int64
# cocaine
# 0    602
# 1    401
# Name: count, dtype: int64
# crack
# 0    806
# 1    197
# Name: count, dtype: int64
# heroin
# 0    739
# 1    264
# Name: count, dtype: int64
# pcp
# 0    956
# 1     47
# Name: count, dtype: int64
# otherdrug
# 0    970
# 1     33
# Name: count, dtype: int64
# nondrug
# 0    873
# 1    129
# 2      1
# Name: count, dtype: int64
# priorarr
# 1    856
# 0    147
# Name: count, dtype: int64
# priorfelarr
# 1    721
# 0    282
# Name: count, dtype: int64
# priordrugarr
# 1    724
# 0    279
# Name: count, dtype: int64
# priorfeldrugarr
# 1    555
# 0    448
# Name: count, dtype: int64
# priorcon
# 1    673
# 0    330
# Name: count, dtype: int64
# priorfelcon
# 1    541
# 0    462
# Name: count, dtype: int64
# priordrugcon
# 1    551
# 0    452
# Name: count, dtype: int64
# priorfeldrugcon
# 0    574
# 1    429
# ...

# %%
print(judges['age'].mean(), judges['age'].std())
# Out:
# 33.08773678963111 11.25410899289963
