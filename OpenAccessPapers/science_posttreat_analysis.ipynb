# %%
import pandas as pd

# %%
# first attempt -question phrased as open 
science_abstract = pd.read_csv("open_access_results/science_posttreat_abstracts.csv")
science_abstract[science_abstract["response"].str.contains("science", case=False, na=False)] # suggests journals with Science in the name, but none are Science
science_abstract[science_abstract["response"] == "Science"]
# Out:
# Empty DataFrame
# Columns: [Journal, Year, Volume, Issue, Beginning page, Article Title, Authors, Article type, No. References, Page length, Open Access, Self-archived, Times cited (12mo), Times cited (18mo), Times cited (24mo), Times cited (30mo), Times cited (36mo), extra_info, journal_info, title, authors, author_info, abstract, doi, num_paragraphs, extra_comments, question, response]
# Index: []
#
# [0 rows x 28 columns]

# %%
# second attempt, given choice of 4 
science_abstract2 = pd.read_csv("open_access_results/science_posttreat_abstracts2.csv")
science_abstract2['response'].value_counts(normalize = True)
